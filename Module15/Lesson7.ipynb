# %% [markdown]
# Используем уже известный нам набор данных "International Airline Passengers" (количество международных авиапассажиров за месяц). Этот датасет доступен в интернете и часто используется для демонстрации методов анализа временных рядов.
# В этом задании мы создадим модель LSTM для предсказания количества пассажиров на основе предыдущих данных.
#
# ### Задание: Прогнозирование временного ряда с использованием LSTM
#
# #### Цель
# Создать и обучить модель LSTM для предсказания количества международных авиапассажиров на основе временного ряда.
#
# #### Теория
#
# - **Модель LSTM** может использоваться для предсказания последовательности значений на основе предыдущих наблюдений. Она хорошо справляется с задачами, где важно учитывать зависимость данных во времени.
#
# #### Описание кода
#
# 1. **Выбор и загрузка набора данных:**
#    Мы используем набор данных "International Airline Passengers", который можно загрузить с помощью URL.
#
# 2. **Предобработка данных:**
#    - Нормализация данных.
#    - Создание обучающих и тестовых выборок.
#    - Формирование временных окон для данных.
#
# 3. **Создание и обучение модели:**
#    - Построение модели LSTM для предсказания временного ряда.
#    - Обучиние модели на тренировочных данных.
#
# 4. **Оценка модели и визуализация результатов:**
#    - Оценим модель на тестовых данных.
#    - Визуализируем реальные и предсказанные значения.
#
#
# ### Домашнее задание
#
# 1. **Улучшение модели:**
#    - Измените архитектуру модели, добавив больше слоев или изменив количество нейронов.
#    - Попробуйте различные гиперпараметры, такие как количество эпох, размер батча и функции активации.
#
# 2. **Анализ результатов:**
#    - Оцените модель с использованием метрик, таких как среднеквадратичная ошибка (MSE) или средняя абсолютная ошибка (MAE).
#    - Исследуйте влияние различных временных окон на качество прогноза.
#
# 3. **Отправьте ссылку на ваш блокнот в Colab преподавателю.**

# %%
# Импорт необходимых библиотек
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Input
import requests
import io

# Загрузка данных
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv"
data = pd.read_csv(io.StringIO(requests.get(url).text))

# Просмотр первых строк данных
print(data.head())

# Преобразование данных
data = data['Passengers'].values.astype(float)

# Нормализация данных
scaler = MinMaxScaler(feature_range=(0, 1))
data_normalized = scaler.fit_transform(data.reshape(-1, 1))

# Создание обучающих и тестовых выборок
def create_dataset(data, time_step=1):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

time_step = 10
X, y = create_dataset(data_normalized, time_step)

# Разделение на обучающие и тестовые данные
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size
X_train, X_test = X[0:train_size], X[train_size:]
y_train, y_test = y[0:train_size], y[train_size:]

# Изменение формы данных для LSTM [samples, time steps, features]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Построение модели LSTM
model = Sequential()
model.add(Input(shape=(time_step, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Компиляция и обучение модели
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=1, epochs=50)

# Предсказание и оценка модели
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Обратное преобразование предсказанных значений к исходной шкале
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
y_train = scaler.inverse_transform([y_train])
y_test = scaler.inverse_transform([y_test])

# Визуализация результатов
plt.figure(figsize=(10, 6))
plt.plot(scaler.inverse_transform(data_normalized), label='Исходные данные')

# Построение прогноза для обучающей выборки
plt.plot(np.arange(time_step, train_size + time_step), train_predict, label='Прогноз (обучение)')

# Построение прогноза для тестовой выборки
plt.plot(np.arange(train_size + time_step, train_size + time_step + len(test_predict)), test_predict, label='Прогноз (тест)')

plt.legend()
plt.xlabel('Месяцы')
plt.ylabel('Количество пассажиров')
plt.title('Прогнозирование количества международных авиапассажиров с помощью LSTM')
plt.show()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121
# Epoch 1/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0340
# Epoch 2/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0095
# Epoch 3/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0115
# Epoch 4/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0114
# Epoch 5/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0102
# Epoch 6/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0067
# Epoch 7/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0082
# Epoch 8/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0087
# Epoch 9/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0100
# Epoch 10/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0056
# Epoch 11/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0059
# Epoch 12/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0030
# Epoch 13/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0032
# Epoch 14/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0024
# Epoch 15/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0030
# Epoch 16/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0034
# Epoch 17/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0021
# Epoch 18/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0024
# Epoch 19/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0023
# Epoch 20/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0026
# Epoch 21/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0023
# Epoch 22/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0024
# Epoch 23/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0023
# Epoch 24/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0026
# Epoch 25/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0026
# Epoch 26/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0025
# Epoch 27/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0022
# Epoch 28/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0024
# Epoch 29/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0030
# Epoch 30/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0031
# Epoch 31/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0023
# Epoch 32/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0020
# Epoch 33/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0024
# Epoch 34/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0022
# Epoch 35/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0023
# Epoch 36/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0022
# Epoch 37/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0023
# Epoch 38/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0020
# Epoch 39/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0022
# Epoch 40/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0022
# Epoch 41/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0022
# Epoch 42/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0025
# Epoch 43/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0020
# Epoch 44/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0028
# Epoch 45/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0016
# Epoch 46/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0022
# Epoch 47/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0018
# Epoch 48/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0018
# Epoch 49/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0019
# Epoch 50/50
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0018
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Импорт необходимых библиотек
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Input
import requests
import io
from tensorflow.keras.losses import MSE, MAE

# Загрузка данных
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv"
data = pd.read_csv(io.StringIO(requests.get(url).text))

# Просмотр первых строк данных
print(data.head())

# Преобразование данных
data = data['Passengers'].values.astype(float)

# Нормализация данных
scaler = MinMaxScaler(feature_range=(0, 1))
data_normalized = scaler.fit_transform(data.reshape(-1, 1))

# Создание обучающих и тестовых выборок
def create_dataset(data, time_step=1):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

time_step = 10
X, y = create_dataset(data_normalized, time_step)

# Разделение на обучающие и тестовые данные
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size
X_train, X_test = X[0:train_size], X[train_size:]
y_train, y_test = y[0:train_size], y[train_size:]

# Изменение формы данных для LSTM [samples, time steps, features]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Построение модели LSTM
model = Sequential()
model.add(Input(shape=(time_step, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Компиляция и обучение модели
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=20, epochs=50)

# Предсказание и оценка модели
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

mae = MAE(y_test, test_predict)
mse = MSE(y_test, test_predict)

plt.figure(figsize=(10, 6))
plt.plot(mae, label='MSE')
plt.plot(mse, label='MSA')
plt.legend()
plt.xlabel('X')
plt.xlabel('Y')
plt.title('График среднеквадратичной и среднеабсолютной ошибок')
plt.show()

# Обратное преобразование предсказанных значений к исходной шкале
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
y_train = scaler.inverse_transform([y_train])
y_test = scaler.inverse_transform([y_test])

# Визуализация результатов
plt.figure(figsize=(10, 6))
plt.plot(scaler.inverse_transform(data_normalized), label='Исходные данные')

# Построение прогноза для обучающей выборки
plt.plot(np.arange(time_step, train_size + time_step), train_predict, label='Прогноз (обучение)')

# Построение прогноза для тестовой выборки
plt.plot(np.arange(train_size + time_step, train_size + time_step + len(test_predict)), test_predict, label='Прогноз (тест)')

plt.legend()
plt.xlabel('Месяцы')
plt.ylabel('Количество пассажиров')
plt.title('Прогнозирование количества международных авиапассажиров с помощью LSTM')
plt.show()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0835
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0193
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0213
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0105
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0120
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0112
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0085
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0089
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0079
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0084
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0081
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0081
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0079
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0075
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0092
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0080
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0094
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0081
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0069
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0087
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0077
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0069
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0087
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0081
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0082
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0091
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0076
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0084
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0085
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0070
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0114
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0086
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0081
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0068
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0079
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0084
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0064
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0078
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0086
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0070
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0078
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0082
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0079
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0067
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0078
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0083
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0073
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0075
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0072
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0064
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d4d2116d090> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 1s 400ms/step
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d4d2116d090> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
